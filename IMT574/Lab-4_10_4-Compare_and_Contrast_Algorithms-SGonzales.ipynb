# %% [markdown]
# # Lab 4.10.4: Compare and Contrast Algorithms
# Step 1: Take any of the problems from before—one where we used logistic regression or kNN and try it with decision trees and random forest algorithms now.<p>
#
# Select one of the below:<p>
#  - <b>Lab 3.8.1: Classifiers—hsbdemo Dataset </b>
#  - Lab 3.8.2: Classifiers—Weather Dataset
#  - Lab 3.8.3: Testing Accuracy—Accident Survivors Dataset
#
# Step 2: Compare and contrast these algorithms.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('LAB 3.8.1-hsbdemo.csv')
print(df.columns)
display(df.head(2))
df.describe()
# Out:
# Index(['Unnamed: 0', 'id', 'female', 'ses', 'schtyp', 'prog', 'read', 'write',
#        'math', 'science', 'socst', 'honors', 'awards', 'cid'],
#       dtype='object')
#    Unnamed: 0   id  female     ses  schtyp      prog  read  write  math  \
# 0           1   45  female     low  public  vocation    34     35    41
# 1           2  108    male  middle  public   general    34     33    41
#
#    science  socst        honors  awards  cid
# 0       29     26  not enrolled       0    1
# 1       36     36  not enrolled       0    1
#        Unnamed: 0          id        read       write        math     science  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  100.500000   52.230000   52.775000   52.645000   51.850000
# std     57.879185   57.879185   10.252937    9.478586    9.368448    9.900891
# min      1.000000    1.000000   28.000000   31.000000   33.000000   26.000000
# ...

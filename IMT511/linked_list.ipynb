# %% [markdown]
# 5. The first step will be to calculate the degree count of each node. Create a new variable node_degree_dict. This variable will be a dictionary where the keys are the names of each node, and the values are another dictionary containing an "in", "out" key with the values that are the in-degree and out-degree numbers respectively. Thus, your variable will have the format:
#
# {
#     'Áedán_mac_Gabráin': {'out': 11}
#     'Bede': {'in': 27, 'out': 12}
#     'Columba': {'in': 13, 'out': 10}
#     'Dál_Riata': {'in': 14, 'out': 18}
#     'Great_Britain': {'in': 180, 'out': 35}
# }
# Yes, this is a dictionary of dictionaries! That means you'll need multiple levels of access.
#
# To create this dictionary, think about looping through all of the links, adding 1 to the "in" or "out" of the appropriate dictionaries. This will be a similar process to the count/frequency calculations you've done before. Remember that each link will need to add to the "in" of one node and the "out" of another.
#
# Tip: Throughout this assignment, I recommend including data type in your variable names (e.g., variable_string, variable_dict, etc). This can help a lot in keeping track of all of the pieces of this complex data structure!
# Be careful about printing out the entire dictionary (there are 4592 unique nodes!). But you can use the above example to check some specific values.
# While not required, it can be useful to make sure that every value dictionary has both an "in" and an "out" key, even if the values at those keys are 0. This will allow you use bracket notation instead of .get() calls more commonly throughout the assignment.

# %%
data_links_lines_cleaned = ['Áedán_mac_Gabráin\tMonarchy\n', 'Áedán_mac_Gabráin\tOrkney\n', 'Áedán_mac_Gabráin\tPicts\n', 'Áedán_mac_Gabráin\tScotland\n', 'Áedán_mac_Gabráin\tWales\n', 'Åland\t20th_century\n', 'Åland\tBaltic_Sea\n', 'Åland\tCrimean_War\n', 'Åland\tCurrency\n', 'Åland\tEuro\n', 'Åland\tEuropean_Union\n', 'Åland\tFinland\n', 'Åland\tLeague_of_Nations\n', 'Åland\tList_of_countries_by_system_of_government\n', 'Åland\tNationality\n', 'Åland\tParliamentary_system\n', 'Åland\tPolice\n', 'Åland\tRussia\n', 'Åland\tStockholm\n', 'Åland\tSweden\n', 'Åland\tTime_zone\n', 'Åland\tTourism\n', 'Åland\tUnited_Kingdom\n', 'Åland\tWorld_War_II\n', 'Édouard_Manet\tAbsinthe\n', 'Édouard_Manet\tBeer\n', 'Édouard_Manet\tClaude_Monet\n', 'Édouard_Manet\tDiego_Velázquez\n', 'Édouard_Manet\tEdgar_Allan_Poe\n', 'Édouard_Manet\tFrance\n', 'Édouard_Manet\tFrancisco_Goya\n', 'Édouard_Manet\tGermany\n', 'Édouard_Manet\tImpressionism\n', 'Édouard_Manet\tItaly\n', 'Édouard_Manet\tLandscape\n', 'Édouard_Manet\tNetherlands\n', 'Édouard_Manet\tPainting\n', 'Édouard_Manet\tParis\n', 'Édouard_Manet\tPhotography\n', 'Édouard_Manet\tRaphael\n', 'Édouard_Manet\tRenaissance\n', 'Édouard_Manet\tSweden\n', 'Édouard_Manet\tUnited_States_dollar\n', 'Édouard_Manet\tWashington,_D.C.\n', 'Éire\tCanada\n', 'Éire\tEnglish_language\n', 'Éire\tGeorge_VI_of_the_United_Kingdom\n', 'Éire\tIreland\n', 'Éire\tNorthern_Ireland\n', 'Éire\tOttawa\n', 'Éire\tRepublic_of_Ireland\n', 'Éire\tUnited_Kingdom\n', 'Óengus_I_of_the_Picts\tDál_Riata\n', 'Óengus_I_of_the_Picts\tDurham\n', 'Óengus_I_of_the_Picts\tEngland\n', 'Óengus_I_of_the_Picts\tGreat_Britain\n', 'Óengus_I_of_the_Picts\tIreland\n', 'Óengus_I_of_the_Picts\tLion\n', 'Óengus_I_of_the_Picts\tMercia\n', 'Óengus_I_of_the_Picts\tScotland\n', 'Óengus_I_of_the_Picts\tViking\n', 'Óengus_I_of_the_Picts\tYork\n', '€2_commemorative_coins\tAthens\n', '€2_commemorative_coins\tAtlantic_Ocean\n', '€2_commemorative_coins\tAustria\n', '€2_commemorative_coins\tBelgium\n', '€2_commemorative_coins\tBerlin\n', '€2_commemorative_coins\tBrussels\n', '€2_commemorative_coins\tCathedral_of_Magdeburg\n', '€2_commemorative_coins\tCereal\n', '€2_commemorative_coins\tChristopher_Columbus\n', '€2_commemorative_coins\tCologne\n', '€2_commemorative_coins\tComet\n', '€2_commemorative_coins\tDresden\n', '€2_commemorative_coins\tEuropean_Union\n', '€2_commemorative_coins\tFinland\n', '€2_commemorative_coins\tFrance\n', '€2_commemorative_coins\tGalileo_Galilei\n', '€2_commemorative_coins\tGermany\n', '€2_commemorative_coins\tGreece\n', '€2_commemorative_coins\tHamburg\n', '€2_commemorative_coins\tHarold_Macmillan\n', '€2_commemorative_coins\tHeraldry\n', '€2_commemorative_coins\tHistory\n', '€2_commemorative_coins\tIreland\n', '€2_commemorative_coins\tItaly\n', '€2_commemorative_coins\tLuxembourg\n', '€2_commemorative_coins\tMaize\n', '€2_commemorative_coins\tMiguel_de_Cervantes\n', '€2_commemorative_coins\tMonaco\n', '€2_commemorative_coins\tMunich\n', '€2_commemorative_coins\tNetherlands\n', '€2_commemorative_coins\tNumismatics\n', '€2_commemorative_coins\tNutrition\n']

# %%
links_list = [{'source': x.split('\t')[0].strip(), 'target': x.split('\t')[1].strip()} for x in data_links_lines_cleaned]
print(links_list[:5])
# Out:
# [{'source': 'Áedán_mac_Gabráin', 'target': 'Monarchy'}, {'source': 'Áedán_mac_Gabráin', 'target': 'Orkney'}, {'source': 'Áedán_mac_Gabráin', 'target': 'Picts'}, {'source': 'Áedán_mac_Gabráin', 'target': 'Scotland'}, {'source': 'Áedán_mac_Gabráin', 'target': 'Wales'}]

# %% [markdown]
# The first step will be to calculate the degree count of each node. Create a new variable node_degree_dict. This variable will be a dictionary where the keys are the names of each node, and the values are another dictionary containing an "in", "out" key with the values that are the in-degree and out-degree numbers respectively. Thus, your variable will have the format:
#
# {
#     'Áedán_mac_Gabráin': {'out': 11}
#     'Bede': {'in': 27, 'out': 12}
#     'Columba': {'in': 13, 'out': 10}
#     'Dál_Riata': {'in': 14, 'out': 18}
#     'Great_Britain': {'in': 180, 'out': 35}
# }
# Yes, this is a dictionary of dictionaries! That means you'll need multiple levels of access.
#
# To create this dictionary, think about looping through all of the links, adding 1 to the "in" or "out" of the appropriate dictionaries. This will be a similar process to the count/frequency calculations you've done before. Remember that each link will need to add to the "in" of one node and the "out" of another.
#
# Tip: Throughout this assignment, I recommend including data type in your variable names (e.g., variable_string, variable_dict, etc). This can help a lot in keeping track of all of the pieces of this complex data structure!
# Be careful about printing out the entire dictionary (there are 4592 unique nodes!). But you can use the above example to check some specific values.
# While not required, it can be useful to make sure that every value dictionary has both an "in" and an "out" key, even if the values at those keys are 0. This will allow you use bracket notation instead of .get() calls more commonly throughout the assignment.

# %%
node_degree_dict = {}
for o in links_list:
    source = o['source']
    if not node_degree_dict.get(source):
        node_degree_dict[source] = {'out': 0}
    node_degree_dict[source]['out'] += 1

    target = o['target']
    if not node_degree_dict.get(target):
        node_degree_dict[target] = {'in': 0}
    node_degree_dict[target]['in'] += 1
print(node_degree_dict)
# Out:
# {'Áedán_mac_Gabráin': {'out': 5}, 'Monarchy': {'in': 1}, 'Orkney': {'in': 1}, 'Picts': {'in': 1}, 'Scotland': {'in': 2}, 'Wales': {'in': 1}, 'Åland': {'out': 19}, '20th_century': {'in': 1}, 'Baltic_Sea': {'in': 1}, 'Crimean_War': {'in': 1}, 'Currency': {'in': 1}, 'Euro': {'in': 1}, 'European_Union': {'in': 2}, 'Finland': {'in': 2}, 'League_of_Nations': {'in': 1}, 'List_of_countries_by_system_of_government': {'in': 1}, 'Nationality': {'in': 1}, 'Parliamentary_system': {'in': 1}, 'Police': {'in': 1}, 'Russia': {'in': 1}, 'Stockholm': {'in': 1}, 'Sweden': {'in': 2}, 'Time_zone': {'in': 1}, 'Tourism': {'in': 1}, 'United_Kingdom': {'in': 2}, 'World_War_II': {'in': 1}, 'Édouard_Manet': {'out': 20}, 'Absinthe': {'in': 1}, 'Beer': {'in': 1}, 'Claude_Monet': {'in': 1}, 'Diego_Velázquez': {'in': 1}, 'Edgar_Allan_Poe': {'in': 1}, 'France': {'in': 2}, 'Francisco_Goya': {'in': 1}, 'Germany': {'in': 2}, 'Impressionism': {'in': 1}, 'Italy': {'in': 2}, 'Landscape': {'in': 1}, 'Netherlands': {'in': 2}, 'Painting': {'in': 1}, 'Paris': {'in': 1}, 'Photography': {'in': 1}, 'Raphael': {'in': 1}, 'Renaissance': {'in': 1}, 'United_States_dollar': {'in': 1}, 'Washington,_D.C.': {'in': 1}, 'Éire': {'out': 8}, 'Canada': {'in': 1}, 'English_language': {'in': 1}, 'George_VI_of_the_United_Kingdom': {'in': 1}, 'Ireland': {'in': 3}, 'Northern_Ireland': {'in': 1}, 'Ottawa': {'in': 1}, 'Republic_of_Ireland': {'in': 1}, 'Óengus_I_of_the_Picts': {'out': 10}, 'Dál_Riata': {'in': 1}, 'Durham': {'in': 1}, 'England': {'in': 1}, 'Great_Britain': {'in': 1}, 'Lion': {'in': 1}, 'Mercia': {'in': 1}, 'Viking': {'in': 1}, 'York': {'in': 1}, '€2_commemorative_coins': {'out': 32}, 'Athens': {'in': 1}, 'Atlantic_Ocean': {'in': 1}, 'Austria': {'in': 1}, 'Belgium': {'in': 1}, 'Berlin': {'in': 1}, 'Brussels': {'in': 1}, 'Cathedral_of_Magdeburg': {'in': 1}, 'Cereal': {'in': 1}, 'Christopher_Columbus': {'in': 1}, 'Cologne': {'in': 1}, 'Comet': {'in': 1}, 'Dresden': {'in': 1}, 'Galileo_Galilei': {'in': 1}, 'Greece': {'in': 1}, 'Hamburg': {'in': 1}, 'Harold_Macmillan': {'in': 1}, 'Heraldry': {'in': 1}, 'History': {'in': 1}, 'Luxembourg': {'in': 1}, 'Maize': {'in': 1}, 'Miguel_de_Cervantes': {'in': 1}, 'Monaco': {'in': 1}, 'Munich': {'in': 1}, 'Numismatics': {'in': 1}, 'Nutrition': {'in': 1}}

# %%
small_group = get_neighborhood("Seattle,_Washington", 1)
print(small_group)
neighborhood_graph = graph.subgraph(small_group)
print(neighborhood_graph)

# %%
plt.figure(figsize=(12, 8))
nx.draw_spring(neighborhood_graph, with_labels=True, node_size=1000, font_size=8,
                node_color='lightblue', edge_color='gray', arrows=True, arrowsize=20)
plt.show()
